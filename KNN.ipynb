# %%
import pandas as pd

# %%
df_train = pd.read_csv('modified_data_train.csv')
df_test = pd.read_csv('modified_data_test.csv')

# %%
df_train.head()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0          0.0            2.0      21  0.26775   3630.7   4512.7   9.2949
# 1          0.0            2.0      22  0.26725   3645.0   4459.4   9.2806
# 2          0.0            2.0      23  0.25875   3712.7   4503.8   9.4355
# 3          0.0            2.0      24  0.25368   3690.8   4512.4   9.3769
# 4          0.0            2.0      25  0.24452   3637.5   4494.1   9.2725
#
#    xmeas_5  xmeas_6  xmeas_7  ...  xmeas_38  xmeas_39  xmeas_40  xmeas_41  \
# 0   26.917   42.466   2701.7  ...   0.84308  0.089922    52.845    43.879
# 1   26.676   42.548   2704.6  ...   0.84308  0.089922    52.845    43.879
# 2   26.791   42.003   2708.2  ...   0.84308  0.089922    52.845    43.879
# 3   26.847   42.168   2709.4  ...   0.84308  0.089922    52.845    43.879
# 4   26.962   42.451   2706.5  ...   0.84308  0.089922    52.845    43.879
#
#     xmv_1   xmv_2   xmv_3   xmv_4   xmv_5  xmv_10
# 0  62.838  54.111  26.634  60.788  22.682  40.947
# 1  62.592  54.749  26.683  62.394  22.758  40.933
# 2  63.004  54.295  24.993  59.951  22.822  41.592
# 3  63.381  54.193  25.491  62.203  22.790  41.633
# 4  62.087  53.604  24.069  62.409  22.490  41.209
#
# [5 rows x 41 columns]

# %%
df_test.head()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0            0            2.0      21  0.25673   3668.3   4510.3   9.3270
# 1            0            2.0      22  0.25728   3644.0   4482.8   9.3429
# 2            0            2.0      23  0.30579   3692.9   4515.2   9.2993
# 3            0            2.0      24  0.30538   3729.0   4512.3   9.3040
# 4            0            2.0      25  0.27300   3678.1   4517.3   9.2570
#
#    xmeas_5  xmeas_6  xmeas_7  ...  xmeas_38  xmeas_39  xmeas_40  xmeas_41  \
# 0   26.645   42.457   2702.8  ...   0.84462   0.11533    53.435    43.598
# 1   26.699   42.166   2704.1  ...   0.84462   0.11533    53.435    43.598
# 2   26.911   42.110   2704.3  ...   0.84462   0.11533    53.435    43.598
# 3   26.702   42.511   2704.7  ...   0.84462   0.11533    53.435    43.598
# 4   26.836   42.018   2707.7  ...   0.84462   0.11533    53.435    43.598
#
#     xmv_1      xmv_2   xmv_3   xmv_4   xmv_5  xmv_10
# 0  62.260  54.109762  25.195  62.105  21.872  40.220
# 1  62.680  54.109762  25.141  63.101  22.188  41.331
# 2  63.068  54.109762  30.283  61.538  22.238  40.438
# 3  62.446  54.109762  30.324  61.499  22.183  41.357
# 4  62.302  54.109762  26.451  63.040  22.605  40.912
#
# [5 rows x 41 columns]

# %%
df_train['binary_fault'] = df_train['faultNumber'].apply(lambda x: 0 if x == 0 else 1)
df_test['binary_fault'] = df_test['faultNumber'].apply(lambda x: 0 if x == 0 else 1)


drop_cols = ['faultNumber', 'simulationRun', 'sample', 'binary_fault']
X_train = df_train.drop(columns=drop_cols, errors='ignore')
y_train = df_train['binary_fault']
X_test =  df_test.drop(columns=drop_cols, errors='ignore')
y_test =  df_test['binary_fault']
common_cols = sorted(list(set(X_train.columns).intersection(set(X_test.columns))))
X_train = X_train[common_cols]
X_test  = X_test[common_cols]

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_val1 = knn.predict(X_val)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_val, y_val1)
print('Validation Accuracy: ', accuracy)
print('Classification Report: ')
print(classification_report(y_val, y_val1))
# Out:
# Validation Accuracy:  0.9457947530864198
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       274
#            1       0.95      1.00      0.97      4910
#
#     accuracy                           0.95      5184
#    macro avg       0.47      0.50      0.49      5184
# weighted avg       0.90      0.95      0.92      5184

# %%
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, y_pred)
print('Test Accuracy: ', accuracy)
print('Classification Report: ')
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy:  0.9423758865248227
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.13      0.01      0.01      2820
#            1       0.94      1.00      0.97     47940
#
#     accuracy                           0.94     50760
#    macro avg       0.54      0.50      0.49     50760
# weighted avg       0.90      0.94      0.92     50760

# %%
y_train.value_counts()
# Out:
# binary_fault
# 1    19570
# 0     1166
# Name: count, dtype: int64

# %%
y_train.shape
# Out:
# (20736,)

# %%
from imblearn.over_sampling import SMOTE
  
smote = SMOTE(sampling_strategy='auto')  
X_train_ro, y_train_ro = smote.fit_resample(X_train, y_train)

# %%
knn_1 = KNeighborsClassifier(n_neighbors=5)

# %%
knn_1.fit(X_train_ro, y_train_ro)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_1.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Test Accuracy:', accuracy)
print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.6505319148936171
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.10      0.66      0.17      2820
#            1       0.97      0.65      0.78     47940
#
#     accuracy                           0.65     50760
#    macro avg       0.53      0.65      0.48     50760
# weighted avg       0.92      0.65      0.74     50760

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(sampling_strategy='auto')
X_train_ru, y_train_ru = rus.fit_resample(X_train, y_train)

# %%
knn_2 = KNeighborsClassifier(n_neighbors=5)

# %%
knn_2.fit(X_train_ru,y_train_ru)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn_2.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Test Accuracy:', accuracy)
print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.45573286052009454
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.09      0.90      0.16      2820
#            1       0.99      0.43      0.60     47940
#
#     accuracy                           0.46     50760
#    macro avg       0.54      0.67      0.38     50760
# weighted avg       0.94      0.46      0.57     50760

# %%
X_train = df_train.drop(columns=drop_cols, errors='ignore')
y_train = df_train['faultNumber']

# %%
y_train.value_counts()
# Out:
# faultNumber
# 0.0     1440
# 1.0     1440
# 19.0    1440
# 18.0    1440
# 17.0    1440
# 16.0    1440
# 14.0    1440
# 13.0    1440
# 12.0    1440
# 11.0    1440
# 10.0    1440
# 8.0     1440
# 7.0     1440
# 6.0     1440
# 5.0     1440
# 4.0     1440
# 2.0     1440
# 20.0    1440
# Name: count, dtype: int64

# %%
X_test = df_test.drop(columns=drop_cols, errors='ignore')
y_test = df_test['faultNumber']

# %%
y_test.value_counts()
# Out:
# faultNumber
# 0     2820
# 1     2820
# 19    2820
# 18    2820
# 17    2820
# 16    2820
# 14    2820
# 13    2820
# 12    2820
# 11    2820
# 10    2820
# 8     2820
# 7     2820
# 6     2820
# 5     2820
# 4     2820
# 2     2820
# 20    2820
# Name: count, dtype: int64

# %%
common_cols = sorted(list(set(X_train.columns).intersection(set(X_test.columns))))
X_train = X_train[common_cols]
X_test  = X_test[common_cols]

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.36
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.10      0.46      0.17      2820
#            1       0.92      0.83      0.88      2820
#            2       0.75      0.81      0.78      2820
#            4       0.41      0.28      0.33      2820
#            5       0.13      0.19      0.16      2820
#            6       0.99      0.84      0.91      2820
#            7       0.82      0.71      0.76      2820
#            8       0.52      0.23      0.32      2820
#           10       0.14      0.15      0.15      2820
#           11       0.12      0.05      0.07      2820
#           12       0.31      0.19      0.23      2820
#           13       0.71      0.45      0.56      2820
#           14       0.76      0.13      0.22      2820
#           16       0.14      0.15      0.15      2820
#           17       0.24      0.19      0.21      2820
#           18       0.55      0.60      0.57      2820
#           19       0.11      0.07      0.09      2820
#           20       0.29      0.21      0.24      2820
#
#     accuracy                           0.36     50760
#    macro avg       0.45      0.36      0.38     50760
# weighted avg       0.45      0.36      0.38     50760
